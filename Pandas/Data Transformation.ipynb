# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("IMDb")
# Out:
#                  Actor                      Film  Year            Genre  \
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("IMDb",ascending=False)
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values(["Year","IMDb"])
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2 = df.sort_values("IMDb")

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.sort_values(["Year","IMDb"],inplace = True)

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index()
# Out:
#     index               Actor                      Film  Year  \
# 0       2          Aamir Khan                    Dangal  2016
# 1       1         Salman Khan           Tiger Zinda Hai  2017
# 2      10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 3       4       Ranveer Singh                 Padmaavat  2018
# 4       6       Rajkummar Rao                     Stree  2018
# 5       5  Ayushmann Khurrana                 Andhadhun  2018
# 6       7      Hrithik Roshan                       War  2019
# 7       8        Akshay Kumar                Good Newwz  2019
# 8      11       Vicky Kaushal  Uri: The Surgical Strike  2019
# 9       3       Ranbir Kapoor                Brahmastra  2022
# 10      9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 11      0      Shah Rukh Khan                   Pathaan  2023
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0         Biography                  2024   8.4
# 1            Action                   565   6.0
# ...

# %%
df2.reset_index(drop = True, inplace = True)

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2["Year"].rank()
# Out:
# 0      1.0
# 1      2.5
# 2      2.5
# 3      5.0
# 4      5.0
# 5      5.0
# 6      8.0
# 7      8.0
# 8      8.0
# 9     10.5
# 10    10.5
# 11    12.0
# Name: Year, dtype: float64

# %%
df2["Rank"]=df2["BoxOffice(INR Crore)"].rank()

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
# ...

# %%
df2.rename(columns={"Film": "Movies"}, inplace=True)

# %%
df2
# Out:
#                  Actor                    Movies  Year            Genre  \
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index(drop = True,inplace = True)

# %%
df2
# Out:
#                  Actor                    Movies  Year            Genre  \
# 0        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 1        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 2          Salman Khan           Tiger Zinda Hai  2017           Action
# 3         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4       Hrithik Roshan                       War  2019           Action
# 5         Akshay Kumar                Good Newwz  2019           Comedy
# 6        Ranveer Singh                 Padmaavat  2018       Historical
# 7       Shah Rukh Khan                   Pathaan  2023           Action
# 8        Rajkummar Rao                     Stree  2018    Horror Comedy
# 9        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 10  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 11          Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.rename(index={0:"row1",1:"row2"},inplace = True)

# %%
df2
# Out:
#                    Actor                      Film  Year            Genre  \
# 2             Aamir Khan                    Dangal  2016        Biography
# row2         Salman Khan           Tiger Zinda Hai  2017           Action
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4          Ranveer Singh                 Padmaavat  2018       Historical
# 6          Rajkummar Rao                     Stree  2018    Horror Comedy
# 5     Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7         Hrithik Roshan                       War  2019           Action
# 8           Akshay Kumar                Good Newwz  2019           Comedy
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# row1      Shah Rukh Khan                   Pathaan  2023           Action
#
# ...

# %%
df2 = df2[["BoxOffice(INR Crore)", "Film", "IMDb"]]

# %%
df2
# Out:
#       BoxOffice(INR Crore)                      Film  IMDb
# 2                     2024                    Dangal   8.4
# row2                   565           Tiger Zinda Hai   6.0
# 10                     201     Badrinath Ki Dulhania   6.1
# 4                      585                 Padmaavat   7.0
# 6                      180                     Stree   7.5
# 5                      111                 Andhadhun   8.3
# 7                      475                       War   6.5
# 8                      318                Good Newwz   7.0
# 11                     342  Uri: The Surgical Strike   8.2
# 3                      431                Brahmastra   5.6
# 9                      266         Bhool Bhulaiyaa 2   5.9
# row1                  1050                   Pathaan   7.2

# %%
df2.reset_index(drop = True,inplace = True)

# %%
df2
# Out:
#     BoxOffice(INR Crore)                      Film  IMDb
# 0                   2024                    Dangal   8.4
# 1                    565           Tiger Zinda Hai   6.0
# 2                    201     Badrinath Ki Dulhania   6.1
# 3                    585                 Padmaavat   7.0
# 4                    180                     Stree   7.5
# 5                    111                 Andhadhun   8.3
# 6                    475                       War   6.5
# 7                    318                Good Newwz   7.0
# 8                    342  Uri: The Surgical Strike   8.2
# 9                    431                Brahmastra   5.6
# 10                   266         Bhool Bhulaiyaa 2   5.9
# 11                  1050                   Pathaan   7.2

# %%
cols = ["IMDb"] + [col for col in df2.columns if col != "BoxOffice(INR Crore)"]
df2 = df2[cols]

# %%
df2
# Out:
#     IMDb                      Film  IMDb
# 0    8.4                    Dangal   8.4
# 1    6.0           Tiger Zinda Hai   6.0
# 2    6.1     Badrinath Ki Dulhania   6.1
# 3    7.0                 Padmaavat   7.0
# 4    7.5                     Stree   7.5
# 5    8.3                 Andhadhun   8.3
# 6    6.5                       War   6.5
# 7    7.0                Good Newwz   7.0
# 8    8.2  Uri: The Surgical Strike   8.2
# 9    5.6                Brahmastra   5.6
# 10   5.9         Bhool Bhulaiyaa 2   5.9
# 11   7.2                   Pathaan   7.2
