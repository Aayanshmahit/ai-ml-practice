# %%
import numpy as np
np.array([1, 3, 6,9])
# Out:
# array([1, 3, 6, 9])

# %%
l1 = [1 , 5, 6, 8]
l2 = [4 , 6, 3, 9]
list(zip(l1,l2))
# Out:
# [(1, 4), (5, 6), (6, 3), (8, 9)]

# %%
#Using list for speedtest
import time

size = 1_00_0000

l1 = list(range(size))
l2 = list(range(size))

start = time.time()
add = [x+y for x , y in zip(l1,l2)]
end = time.time()
print("time taken is",end - start)
# Out:
# time taken is 0.10588383674621582

# %%
#Using array for speedtest
size = 1_00_0000
arr1 = np.array(l1)
arr2 = np.array(l2)

start = time.time()
add = arr1 + arr2
end = time.time()
print("time taken in array is",end - start)
# Out:
# time taken in array is 0.015465736389160156

# %%
print("type is",type(arr1))
print(arr2.shape)
# Out:
# type is <class 'numpy.ndarray'>
# (1000000,)
