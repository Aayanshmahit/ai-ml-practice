# %%
import numpy as np

# %%
arr = np.array([1 ,3, 5, 6])
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("int32")
# Out:
# array([1, 3, 5, 6], dtype=int32)

# %%
arr2 = np.array([23 ,32, 42 ,42])

# %%
arr2.dtype
# Out:
# dtype('int64')

# %%
arr.nbytes
# Out:
# 32

# %%
arr2.nbytes
# Out:
# 32

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr_int64 = np.array([1, 2, 3], dtype=np.int64)
arr_int32 = np.array([1, 2, 3], dtype=np.int32)
arr_int64.nbytes
arr_int32.nbytes
# Out:
# 12

# %%
print(arr_int64.nbytes)
print(arr_int32.nbytes)
# Out:
# 24
# 12

# %%
print(arr.nbytes)
print(arr2.nbytes)
# Out:
# 32
# 32

# %%
strarr = np.array(['apple','mangovhvfuyjgjs','santra'],dtype = 'U10')

# %%
print(strarr)
# Out:
# ['apple' 'mangovhvfu' 'santra']

# %%
print(strarr.dtype)
# Out:
# <U10

# %%
com = np.array([1 + 2j ,1+3j , 1+5j], dtype = 'complex128')

# %%
print(com)
# Out:
# [1.+2.j 1.+3.j 1.+5.j]
